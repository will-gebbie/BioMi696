# %%
import pandas as pd
import matplotlib.pylab as plt
import numpy as np

# %%
df_nd = pd.read_excel('deseq_and_network_excel_sheets/update_trace_vs_nd.xlsx')
df_la = pd.read_excel('deseq_and_network_excel_sheets/update_trace_vs_la.xlsx')
df_ce = pd.read_excel('deseq_and_network_excel_sheets/update_trace_vs_ce.xlsx')
df_sm = pd.read_excel('deseq_and_network_excel_sheets/update_trace_vs_sm.xlsx')

# %%
fig = plt.figure(figsize=(100,15))
ax = fig.subplots()
x = df['Kb Loc']
ynd = df_nd['log2FoldChange'].where(abs(df_nd['log2FoldChange']) >= 1)
yla = df_la['log2FoldChange'].where(abs(df_la['log2FoldChange']) >= 1)
yce = df_ce['log2FoldChange'].where(abs(df_ce['log2FoldChange']) >= 1)
ysm = df_sm['log2FoldChange'].where(abs(df_sm['log2FoldChange']) >= 1)



title = 'Trace vs Ln\'s log2FoldChange'
ax.scatter(x,ynd, label='l2FC Nd', alpha=0.5)
ax.scatter(x,yla, label='l2FC La', alpha=0.5)
ax.scatter(x,yce, label='l2FC Ce', alpha=0.5)
ax.scatter(x,ysm, label='l2FC Sm', alpha=0.5)
ax.axhline(y=1, color='r', linestyle='-')
ax.axhline(y=-1, color='r', linestyle='-')
plt.xticks(np.arange(min(x), max(x)+1, 100))
plt.xticks(rotation=90)
ax.set_title(title)
ax.set_xlabel("NT Location (Kb)")
ax.set_ylabel("log2FoldChange")
ax.legend(loc='upper right', ncols=3, prop={'size':30})
for item in ([ax.title, ax.xaxis.label, ax.yaxis.label] +
             ax.get_xticklabels() + ax.get_yticklabels()):
    item.set_fontsize(40)
plt.savefig('{}.png'.format(title), bbox_inches = "tight")
plt.show()
